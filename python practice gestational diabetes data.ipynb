# %%
#Importing the dataset in python 
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
pd.options.display.max_columns = None

df = pd.read_excel("cleaned data in python .xlsx")
df
# Out:
#      Unnamed: 0  Participant ID  systolic BP (mmHg) V1  \
# 0           0.0             1.0                  114.0
# 1           1.0             2.0                  178.0
# 2           2.0             3.0                  123.0
# 3           3.0             4.0                  115.0
# 4           4.0             5.0                  116.0
# 5           5.0             6.0                  116.0
# 6           6.0             7.0                  122.0
# 7           7.0             8.0                  139.0
# 8           8.0             9.0                  105.0
# 9           9.0            10.0                  122.0
# 10         10.0            11.0                  112.0
# 11         11.0            12.0                  127.0
# 12         12.0            13.0                  113.0
# 13         13.0            14.0                  123.0
# 14         14.0            15.0                  121.0
# 15         15.0            16.0                  129.0
# ...

# %%
#Replace duplicate colummns 
df.loc[:,~df.columns.str.replace('\.\d+','').duplicated(keep='first')]
# Out:
# /var/folders/3y/mt6kw1sn0gq1dsbmj0c2p24m0000gn/T/ipykernel_71033/878955425.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.loc[:,~df.columns.str.replace('\.\d+','').duplicated(keep='first')]
#      Unnamed: 0  Participant ID  systolic BP (mmHg) V1  \
# 0           0.0             1.0                  114.0
# 1           1.0             2.0                  178.0
# 2           2.0             3.0                  123.0
# 3           3.0             4.0                  115.0
# 4           4.0             5.0                  116.0
# 5           5.0             6.0                  116.0
# 6           6.0             7.0                  122.0
# 7           7.0             8.0                  139.0
# 8           8.0             9.0                  105.0
# 9           9.0            10.0                  122.0
# 10         10.0            11.0                  112.0
# 11         11.0            12.0                  127.0
# ...

# %%
for i in df.columns:
  if df[i].isna().sum() != 0:
    print('null values in', i, 'column :', df[i].isna().sum() )
# Out:
# null values in Smoking 123 column : 3
# null values in Medications V1 column : 569
# null values in 25OHD checked column : 297
# null values in V1 HbA1c (mmol/mol) column : 4
# null values in WCC column : 4
# null values in V1 Hb column : 4
# null values in V1 Platelet column : 4
# null values in V1 Creatinine column : 5
# null values in V1 Calcium column : 304
# null values in V1 Albumin column : 304
# null values in V1 ALT column : 4
# null values in V1 CRP column : 3
# null values in V1 U albumin column : 6
# null values in V1 U protein column : 6
# null values in V1 U creatinine column : 6
# null values in V1 PCR column : 7
# null values in V1 25OHD value (nmol/L) column : 454
# null values in 1h glucose column : 327
# null values in OGTT 1h value high 10.1 column : 360
# null values in GCT OGTT high 10 column : 84
# null values in HbA1c V2 column : 347
# null values in systolic BP (mmHg) V1.1 column : 72
# null values in V1 HbA1c (mmol/mol).1 column : 76
# ...

# %%
len(df.columns)
# Out:
# 64

# %%
pd.set_option('display.max_rows',None)
df.isna().sum()
# Out:
# Unnamed: 0                              0
# Participant ID                          0
# systolic BP (mmHg) V1                   0
# diastolic BP (mmHg) V1                  0
# Pulse (bpm) V1                          0
# Weight (kg) V1                          0
# Height (m) V1                           0
# BMI (kg/m2) V1                          0
# Smoking 123                             3
# Alcohol Intake V1                       0
# Ethnicity V1                            0
# Previous GDM V1                         0
# PMHx V1                                 0
# Chronic Illness V1                      0
# Medications V1                        569
# Age>30                                  0
# Hx GDM, glycosuria, 1st degree rel      0
# HighRisk 10                             0
# Screening method                        0
# GCT 10                                  0
# 25OHD checked                         297
# V1 Gestational Age                      0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Participant ID  systolic BP (mmHg) V1  diastolic BP (mmHg) V1  \
# 0         0.0             1.0                  114.0                    58.0
# 1         1.0             2.0                  178.0                    78.0
# 2         2.0             3.0                  123.0                    62.0
# 3         3.0             4.0                  115.0                    68.0
# 4         4.0             5.0                  116.0                    61.0
#
#    Pulse (bpm) V1  Weight (kg) V1  Height (m) V1  BMI (kg/m2) V1  Smoking 123  \
# 0            73.0            59.4          1.696       20.650699          NaN
# 1            84.0            70.1          1.549       29.215625          NaN
# 2            79.0            64.9          1.578       26.063378          NaN
# 3            82.0            67.1          1.647       24.736333          3.0
# 4            92.0            67.5          1.699       23.383904          3.0
#
# ...

# %%
df['V1 U albumin'] = df['V1 U albumin'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 df['V1 U albumin'] = df['V1 U albumin'].astype(float)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df['V1 U albumin'] = df['V1 U albumin'].replace({"<3.0":2.9,"<5":4.9})
df['V1 U albumin']
# Out:
# 0        2.9
# 1        9.4
# 2        9.1
# 3        2.9
# 4        2.9
# 5        2.9
# 6        2.9
# 7        3.3
# 8       23.3
# 9        9.5
# 10       7.0
# 11       2.9
# 12       5.3
# 13       2.9
# 14       2.9
# 15       6.0
# 16       2.9
# 17       2.9
# 18       2.9
# 19       NaN
# 20       2.9
# 21       2.9
# 22       6.5
# 23       2.9
# 24       3.7
# 25      14.9
# 26       7.8
# 27      33.9
# 28       2.9
# 29       2.9
# 30      36.9
# 31       2.9
# 32       2.9
# 33       2.9
# 34       2.9
# 35       7.0
# 36      18.1
# 37       2.9
# 38       2.9
# 39       4.8
# 40       7.0
# 41       4.2
# 42       6.1
# 43       3.0
# 44       2.9
# 45      12.3
# 46      32.8
# 47       3.3
# 48       7.5
# 49      46.0
# 50       4.1
# 51      13.0
# 52      10.8
# 53       2.9
# 54       5.2
# 55       2.9
# 56     20.06
# 57      25.8
# 58       2.9
# 59       5.8
# 60       9.6
# 61      50.8
# 62       2.9
# 63       5.1
# 64       2.9
# 65      3.46
# ...
